# %% [markdown]
# Exercise work consists of three parts. After each part, take the mini-exam available in Moodle. The questions concern the exercise so read the instructions carefully and make sure you remember to cover all given tasks. <br>
# After the deadline of each mini-exam, example results will be published. This helps you to move to the next part. However, take into account that the deadlines are thus strict, no extensions will be granted! <br>
# Two exam points can be acquired from each mini-exam. All three parts of the exercise are compulsory. Completed exercise work from previous years does not apply for this course.

# %% [markdown]
# **Deadlines for the mini-exams:**
# - Part 1: Fri 9.2.2024 at 23:59
# - Part 2: Fri 23.2024 at 23:59
# - Part 3: Fri 8.3.2024 at 23:59
#
# **If you encounter problems, Google first and if you can’t find an answer, ask for help**
# - Moodle area for questions
# - pekavir@utu.fi
#
# **Grading**
#
# The exercise covers a part of the grading in this course. The course exam has 5 questions, 6 points of each. Exercise gives at maximum 6 points, i.e. the total score is 36 points.

# %% [markdown]
# # Part 1

# %% [markdown]
# Read the original research article:
#
# İ. Çınar and M. Koklu. Identification of rice varieties using machine learning algorithms. Journal of Agricultural Sciences, 28(2):307–325, 2022. doi: 10.15832/ankutbd.862482.
#
# https://dergipark.org.tr/en/download/article-file/1513632
#
# There will be questions regarding the article in the mini-exam.

# %% [markdown]
# Mini-exam questions:<br>
#
# **1. The camera used to take the rice images was placed in a closed box. Why?** <br>
# Answer: To ensure the same lighting environment for all rice samples.
# <br>
#
# **2. Which morphological feature is: The number of pixels in the smallest convex polygon that can accommodate the rice grain area?** <br>
# Answer: Convex_Area
#
# **3. How many color spaces were used to derive the color features in the original article?** <br>
# Answer: 5

# %% [markdown]
# ## Introduction

# %% [markdown]
# Will be written in Part 3.

# %% [markdown]
# ## Preparations of the data

# %% [markdown]
# Make three folders in your working folder: 'notebooks', 'data' and 'training_data'. Save this notebook in 'notebooks' folder.

# %% [markdown]
# Import all the packages needed for this notebook in one cell (add the ones you apply):

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import cv2 as cv

import glob, os
import itertools

from random import sample
from random import seed

from scipy.stats import skew
from scipy.stats import kurtosis

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# Import the images. Data can be found from (downloading starts as you press the link) https://www.muratkoklu.com/datasets/vtdhnd09.php <br>
# Save the data folders 'Arborio', 'Basmati', 'Ipsala', 'Jasmine', and 'Karacadag' in 'data' folder. <br>
# Take a random sample of 100 images from each rice species (i.e. 500 images in total). Use seed(50) for enabling reproducible results.

# %%
# import data
# set the seed for enabling
# the reproduction with the same sequence
seed(50)

path = '../data'
folders = ['Arborio',
           'Basmati',
           'Ipsala',
           'Jasmine',
           'Karacadag']

subset = []
for folder in folders:
    path_folder = os.path.join(path, folder)
    # all .jpg files from the given folder
    files = glob.glob(os.path.join(path_folder, '*.jpg'))
    # gather all sampled filenames in subset list
    subset.extend(sample(files, 100))

# %% [markdown]
#  Gather the sampled images in a list.

# %%
# gather images
ims = []
for filename in subset:
    # image in BGR order
    im = cv.imread(filename)
    ims.append(im)

# %% [markdown]
# We will test the needed functions with one test image. It is 'basmati (244).jpg'. Save this image as test_image.

# %%
test_image_file_name = '../data/Basmati/basmati (244).jpg'
test_image = cv.imread(test_image_file_name)

# %% [markdown]
# Determine the contour of each rice (use *findContours* from OpenCV). <br>
# Determine the contour also for the test_image. <br>
# Plot the original image of the test_image and also its image including the contour. <br>
# Be aware that *drawContours* adds the contour to the original image, so use the copy of the test_image as input for the function!

# %%
# https://docs.opencv.org/4.x/d4/d73/tutorial_py_contours_begin.html
def find_contour(im):
    imgray = cv.cvtColor(im, cv.COLOR_BGR2GRAY)
    ret, thresh = cv.threshold(imgray, 127, 255, 0)
    contours, hierarchy = cv.findContours(thresh,
                                          cv.RETR_TREE,
                                          cv.CHAIN_APPROX_SIMPLE)
    cnt = contours[0]
    
    return(cnt.reshape(-1,2))

# %%
# find contour for the test_image
test_image_cnt = find_contour(test_image)
plt.figure(figsize=(3,3))
# drawCountours arguments:
#image, contours, index of contours, color, thickness
plt.imshow(cv.drawContours(test_image.copy(),
                           [test_image_cnt], 0, (0,255,0), 3));

# %% [markdown]
# Mini-exam question: <br>
# **4. Compare the contours below. Which one is the contour of the test_image?** <br>
# Answer: See thes image below, the contour is the first one (you may have had the images in different order in your mini-exam).

# %%
# find contour for each image in the subset
contour_images = []
cnts = []
ims_with_contours = []
for im in ims:
    # take a copy of the original image
    # in order to avoid adding the contour to the original image
    im = im.copy()
    cnt = find_contour(im)
    cnts.append(cnt)
    ims_with_contours.append(cv.drawContours(im,
                                             [cnt],
                                             0, (0,255,0), 3))

# %%
# just to check that all of the contours look reasonable
i = 0
fig = plt.figure(figsize=(12, 16))
for im in ims_with_contours:
    i+=1
    plt.subplot(25, 20, i)
    plt.imshow(im)
    #get current axes
    ax = plt.gca()
    #hide axes
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
fig.tight_layout(pad=0.4)

# %% [markdown]
# ## Feature extraction

# %% [markdown]
# Gather the color feature data (12 features): <br>
#
# First, convert each RGB image to YCbCr-image. You can use *cvtColor* function from OpenCV with appropriate color conversion. <br>
# Be aware that openCV default channel order is BGR not RGB. In which order does the *cvtColor* function output the components? <br>
#
# Calculate the following color features for each image, including only the pixels within the contour (you can use *pointPolygonTest* from OpenCV)
# - Mean for each YCbCr component
# - Variance for each YCbCr component
# - Skewness for each YCbCr component
# - Kurtosis for each YCbCr component

# %% [markdown]
# Is point x = 125, y = 160 within the contour in the test_image? (x is in horizontal direction, y is in vertical direction)

# %%
x = 125
y = 160

print(cv.pointPolygonTest(test_image_cnt, (x,y), False))
plt.figure(figsize=(4,4))
plt.imshow(cv.drawContours(test_image.copy(),
                           [test_image_cnt], 0, (0,255,0), 3))
plt.plot(x,y,'ro');
# Out:
# 1.0

# %% [markdown]
# Mini-exam question: <br>
# **5. Is the point x = 125, y = 160 within the contour of the test_image? (x = horizontal pixel, y = vertical pixel)** <br>
# Answer: Yes

# %%
def calc_color_features(im, cnt, component):
    
    # change from BGR into YCrCb color space
    im_ycrcb = cv.cvtColor(im, cv.COLOR_BGR2YCrCb)
    
    xs = range(0, im.shape[1])
    ys = range(0, im.shape[0])
    
    xys = list(itertools.product(xs, ys))
    
    # gather the pixels which are within the contour to a list
    comp_values = []
    for x, y in xys:
        
        # check if the point (x,y) is within the contour.
        # Pixels in image [y, x, color_channel]
        if cv.pointPolygonTest(cnt, (x,y), False) == 1:
            comp_values.append(im_ycrcb[y, x, component])     
    
    return(np.mean(comp_values),
           np.var(comp_values),
           skew(comp_values),
           kurtosis(comp_values))

# %% [markdown]
# What are the mean values of Y, Cb and Cr components for the test image (within the contour)?

# %%
print('Y:', calc_color_features(test_image, test_image_cnt, 0)[0])
print('Cb:', calc_color_features(test_image, test_image_cnt, 2)[0])
print('Cr:', calc_color_features(test_image, test_image_cnt, 1)[0])
# Out:
# Y: 223.90895232815964
# Cb: 133.640243902439
# Cr: 126.90562638580931

# %% [markdown]
# Miniexam question: <br>
# **6. The mean value of Cr component is...** <br>
# Answer: Almost the same as Cb component value.

# %% [markdown]
# Gather the dimension feature data (8 features) <br>
# - Fit an ellipse to the contour points (use *fitEllipse* from OpenCV)
# - Plot one example image of each rice species including the fitted ellipse
# - Calculate the following features for each image (for details, see the original article)
#     - the major axis length the ellipse
#     - the minor axis length of the ellipse
#     - area inside the contour (use *contourArea* from OpenCV)
#     - perimeter of the contour (use *arcLength* from OpenCV)
#     - equivalent diameter
#     - compactness
#     - shape factor 1 (SF1)
#     - shape factor 2 (SF2)
#
# Calculate the dimension feature values for the test_image as well. What are the dimension feature values for the test_image?

# %%
def calc_dimension_features(im, cnt):
    
    # fit an ellipse to the contour.
    # Ellipse is a tuple including
    # (center coordinates, axes lengths, angle)
    ellipse = cv.fitEllipse(cnt)
    (cc, (a1, a2), ang) = ellipse
    
    major_a = max(a1, a2)
    minor_a = min(a1, a2)
    
    fig = cv.ellipse(im.copy(), ellipse, (0,0,255), 3)
    
    area = cv.contourArea(cnt)
    perimeter = cv.arcLength(cnt, True)
    
    equivalent_diameter = np.sqrt((4 * area) / (np.pi))
    compactness = equivalent_diameter / major_a
    
    shape_factor1 = major_a / area
    shape_factor2 = minor_a / area
    
    
    return(pd.DataFrame(
        data={'major_axis_length': [major_a],
              'minor_axis_length': [minor_a],
              'area': [area],
              'perimeter': [perimeter],
              'equivalent_diameter': [equivalent_diameter],
              'compactness': [compactness],
             'shape_factor1': [shape_factor1],
             'shape_factor2': [shape_factor2]}), fig)

# %%
calc_dimension_features(test_image, test_image_cnt)[0]
# Out:
#    major_axis_length  minor_axis_length    area   perimeter  \
# 0         194.516296          50.020149  7409.5  430.835568
#
#    equivalent_diameter  compactness  shape_factor1  shape_factor2
# 0            97.129133     0.499337       0.026252       0.006751

# %% [markdown]
# Gather all the features in a dataframe: one sample in one row, including all feature values in columns. <br>
# For each data point, include also information of the original image and the label (rice species). <br>
# Save the data in training_data folder as a parquet file.

# %%
def gather_color_features(im, cnt):
    
    df = []
    
    for component, abbr in enumerate(['y', 'cr', 'cb']):
    
        c_mean, c_var, c_skew, c_kurt = calc_color_features(
            im, cnt, component)
        
        df.append(pd.DataFrame(
            data={'mean_{}'.format(abbr) : [c_mean],
                  'var_{}'.format(abbr) : [c_var],
                  'skew_{}'.format(abbr) : [c_skew],
                  'kurt_{}'.format(abbr) : [c_kurt]
                       }))
                  
    df = pd.concat(df, axis=1)

    return(df)

# %%
# calculate all features and gather them as a dataframe
df = []
ims_with_ellipses = []
for cnt, filename, im in zip(cnts, subset, ims):
    # color features
    df1 = gather_color_features(im, cnt)
    
    # dimension features
    df2, fig = calc_dimension_features(im, cnt)
    ims_with_ellipses.append(fig)
    
    df3 = pd.concat([df1, df2], axis=1)
    df3['class'] = [filename[8:11]]
    
    df.append(df3) 
    print('Features derived for', filename)

df = pd.concat(df, axis=0, ignore_index=True)
df['class_int']= df['class'].map(
    {'Arb': 0, 'Bas':1, 'Ips':2, 'Jas': 3, 'Kar':4})
# Out:
# Features derived for ../data\Arborio\Arborio (3834).jpg
# Features derived for ../data\Arborio\Arborio (9115).jpg
# Features derived for ../data\Arborio\Arborio (13922).jpg
# Features derived for ../data\Arborio\Arborio (1867).jpg
# Features derived for ../data\Arborio\Arborio (5898).jpg
# Features derived for ../data\Arborio\Arborio (9634).jpg
# Features derived for ../data\Arborio\Arborio (13573).jpg
# Features derived for ../data\Arborio\Arborio (671).jpg
# Features derived for ../data\Arborio\Arborio (3475).jpg
# Features derived for ../data\Arborio\Arborio (7806).jpg
# Features derived for ../data\Arborio\Arborio (14865).jpg
# Features derived for ../data\Arborio\Arborio (11253).jpg
# Features derived for ../data\Arborio\Arborio (4438).jpg
# Features derived for ../data\Arborio\Arborio (14678).jpg
# Features derived for ../data\Arborio\Arborio (13306).jpg
# Features derived for ../data\Arborio\Arborio (6472).jpg
# Features derived for ../data\Arborio\Arborio (4706).jpg
# Features derived for ../data\Arborio\Arborio (11254).jpg
# Features derived for ../data\Arborio\Arborio (12258).jpg
# Features derived for ../data\Arborio\Arborio (1617).jpg
# Features derived for ../data\Arborio\Arborio (8668).jpg
# Features derived for ../data\Arborio\Arborio (1145).jpg
# Features derived for ../data\Arborio\Arborio (1621).jpg
# Features derived for ../data\Arborio\Arborio (14707).jpg
# Features derived for ../data\Arborio\Arborio (13277).jpg
# Features derived for ../data\Arborio\Arborio (12785).jpg
# Features derived for ../data\Arborio\Arborio (11010).jpg
# Features derived for ../data\Arborio\Arborio (9242).jpg
# Features derived for ../data\Arborio\Arborio (14849).jpg
# Features derived for ../data\Arborio\Arborio (5400).jpg
# Features derived for ../data\Arborio\Arborio (9669).jpg
# Features derived for ../data\Arborio\Arborio (5456).jpg
# Features derived for ../data\Arborio\Arborio (2821).jpg
# Features derived for ../data\Arborio\Arborio (5861).jpg
# Features derived for ../data\Arborio\Arborio (11309).jpg
# Features derived for ../data\Arborio\Arborio (9997).jpg
# Features derived for ../data\Arborio\Arborio (10941).jpg
# Features derived for ../data\Arborio\Arborio (6719).jpg
# Features derived for ../data\Arborio\Arborio (5402).jpg
# Features derived for ../data\Arborio\Arborio (8662).jpg
# Features derived for ../data\Arborio\Arborio (14927).jpg
# Features derived for ../data\Arborio\Arborio (8203).jpg
# Features derived for ../data\Arborio\Arborio (6681).jpg
# Features derived for ../data\Arborio\Arborio (5981).jpg
# Features derived for ../data\Arborio\Arborio (8779).jpg
# Features derived for ../data\Arborio\Arborio (2842).jpg
# Features derived for ../data\Arborio\Arborio (10081).jpg
# Features derived for ../data\Arborio\Arborio (13348).jpg
# Features derived for ../data\Arborio\Arborio (14974).jpg
# Features derived for ../data\Arborio\Arborio (13923).jpg
# Features derived for ../data\Arborio\Arborio (8276).jpg
# Features derived for ../data\Arborio\Arborio (2903).jpg
# Features derived for ../data\Arborio\Arborio (6820).jpg
# Features derived for ../data\Arborio\Arborio (11558).jpg
# Features derived for ../data\Arborio\Arborio (12963).jpg
# Features derived for ../data\Arborio\Arborio (9929).jpg
# Features derived for ../data\Arborio\Arborio (3025).jpg
# Features derived for ../data\Arborio\Arborio (13996).jpg
# Features derived for ../data\Arborio\Arborio (9861).jpg
# Features derived for ../data\Arborio\Arborio (6709).jpg
# Features derived for ../data\Arborio\Arborio (5068).jpg
# Features derived for ../data\Arborio\Arborio (3280).jpg
# Features derived for ../data\Arborio\Arborio (11865).jpg
# Features derived for ../data\Arborio\Arborio (13975).jpg
# Features derived for ../data\Arborio\Arborio (5686).jpg
# Features derived for ../data\Arborio\Arborio (13083).jpg
# Features derived for ../data\Arborio\Arborio (4373).jpg
# Features derived for ../data\Arborio\Arborio (5036).jpg
# Features derived for ../data\Arborio\Arborio (11809).jpg
# Features derived for ../data\Arborio\Arborio (257).jpg
# Features derived for ../data\Arborio\Arborio (656).jpg
# Features derived for ../data\Arborio\Arborio (5705).jpg
# Features derived for ../data\Arborio\Arborio (9621).jpg
# Features derived for ../data\Arborio\Arborio (6760).jpg
# Features derived for ../data\Arborio\Arborio (8581).jpg
# Features derived for ../data\Arborio\Arborio (11730).jpg
# Features derived for ../data\Arborio\Arborio (9079).jpg
# Features derived for ../data\Arborio\Arborio (5720).jpg
# Features derived for ../data\Arborio\Arborio (811).jpg
# Features derived for ../data\Arborio\Arborio (4516).jpg
# Features derived for ../data\Arborio\Arborio (3813).jpg
# Features derived for ../data\Arborio\Arborio (2793).jpg
# Features derived for ../data\Arborio\Arborio (9586).jpg
# Features derived for ../data\Arborio\Arborio (4129).jpg
# Features derived for ../data\Arborio\Arborio (8515).jpg
# Features derived for ../data\Arborio\Arborio (434).jpg
# Features derived for ../data\Arborio\Arborio (8553).jpg
# Features derived for ../data\Arborio\Arborio (6437).jpg
# Features derived for ../data\Arborio\Arborio (11842).jpg
# Features derived for ../data\Arborio\Arborio (3862).jpg
# Features derived for ../data\Arborio\Arborio (491).jpg
# Features derived for ../data\Arborio\Arborio (8687).jpg
# Features derived for ../data\Arborio\Arborio (4114).jpg
# Features derived for ../data\Arborio\Arborio (14429).jpg
# Features derived for ../data\Arborio\Arborio (11371).jpg
# Features derived for ../data\Arborio\Arborio (9142).jpg
# Features derived for ../data\Arborio\Arborio (1920).jpg
# Features derived for ../data\Arborio\Arborio (7678).jpg
# Features derived for ../data\Arborio\Arborio (4117).jpg
# Features derived for ../data\Arborio\Arborio (12212).jpg
# Features derived for ../data\Basmati\basmati (10097).jpg
# Features derived for ../data\Basmati\basmati (1782).jpg
# Features derived for ../data\Basmati\basmati (1013).jpg
# Features derived for ../data\Basmati\basmati (9839).jpg
# Features derived for ../data\Basmati\basmati (5153).jpg
# Features derived for ../data\Basmati\basmati (6539).jpg
# Features derived for ../data\Basmati\basmati (2558).jpg
# Features derived for ../data\Basmati\basmati (3469).jpg
# Features derived for ../data\Basmati\basmati (8158).jpg
# Features derived for ../data\Basmati\basmati (9035).jpg
# Features derived for ../data\Basmati\basmati (6141).jpg
# Features derived for ../data\Basmati\basmati (872).jpg
# Features derived for ../data\Basmati\basmati (4439).jpg
# Features derived for ../data\Basmati\basmati (8336).jpg
# Features derived for ../data\Basmati\basmati (13303).jpg
# Features derived for ../data\Basmati\basmati (12390).jpg
# Features derived for ../data\Basmati\basmati (720).jpg
# Features derived for ../data\Basmati\basmati (4946).jpg
# Features derived for ../data\Basmati\basmati (11441).jpg
# Features derived for ../data\Basmati\basmati (886).jpg
# Features derived for ../data\Basmati\basmati (12015).jpg
# Features derived for ../data\Basmati\basmati (13775).jpg
# Features derived for ../data\Basmati\basmati (2042).jpg
# Features derived for ../data\Basmati\basmati (8445).jpg
# Features derived for ../data\Basmati\basmati (13621).jpg
# Features derived for ../data\Basmati\basmati (14952).jpg
# Features derived for ../data\Basmati\basmati (10491).jpg
# Features derived for ../data\Basmati\basmati (5829).jpg
# Features derived for ../data\Basmati\basmati (4133).jpg
# Features derived for ../data\Basmati\basmati (10693).jpg
# Features derived for ../data\Basmati\basmati (9095).jpg
# Features derived for ../data\Basmati\basmati (11159).jpg
# Features derived for ../data\Basmati\basmati (6052).jpg
# Features derived for ../data\Basmati\basmati (13494).jpg
# Features derived for ../data\Basmati\basmati (6559).jpg
# Features derived for ../data\Basmati\basmati (13862).jpg
# Features derived for ../data\Basmati\basmati (4289).jpg
# Features derived for ../data\Basmati\basmati (2708).jpg
# Features derived for ../data\Basmati\basmati (3355).jpg
# Features derived for ../data\Basmati\basmati (5013).jpg
# Features derived for ../data\Basmati\basmati (2665).jpg
# Features derived for ../data\Basmati\basmati (7825).jpg
# Features derived for ../data\Basmati\basmati (8603).jpg
# Features derived for ../data\Basmati\basmati (226).jpg
# Features derived for ../data\Basmati\basmati (3430).jpg
# Features derived for ../data\Basmati\basmati (1131).jpg
# Features derived for ../data\Basmati\basmati (2441).jpg
# Features derived for ../data\Basmati\basmati (11784).jpg
# Features derived for ../data\Basmati\basmati (1843).jpg
# Features derived for ../data\Basmati\basmati (10759).jpg
# Features derived for ../data\Basmati\basmati (7929).jpg
# Features derived for ../data\Basmati\basmati (7983).jpg
# Features derived for ../data\Basmati\basmati (10280).jpg
# Features derived for ../data\Basmati\basmati (10994).jpg
# Features derived for ../data\Basmati\basmati (3038).jpg
# Features derived for ../data\Basmati\basmati (6347).jpg
# Features derived for ../data\Basmati\basmati (5927).jpg
# Features derived for ../data\Basmati\basmati (4853).jpg
# Features derived for ../data\Basmati\basmati (10127).jpg
# Features derived for ../data\Basmati\basmati (14531).jpg
# Features derived for ../data\Basmati\basmati (1467).jpg
# Features derived for ../data\Basmati\basmati (911).jpg
# Features derived for ../data\Basmati\basmati (1610).jpg
# Features derived for ../data\Basmati\basmati (4453).jpg
# Features derived for ../data\Basmati\basmati (6007).jpg
# Features derived for ../data\Basmati\basmati (6582).jpg
# Features derived for ../data\Basmati\basmati (4157).jpg
# Features derived for ../data\Basmati\basmati (9638).jpg
# Features derived for ../data\Basmati\basmati (3839).jpg
# Features derived for ../data\Basmati\basmati (11307).jpg
# Features derived for ../data\Basmati\basmati (14443).jpg
# Features derived for ../data\Basmati\basmati (12356).jpg
# Features derived for ../data\Basmati\basmati (2835).jpg
# Features derived for ../data\Basmati\basmati (12893).jpg
# Features derived for ../data\Basmati\basmati (11653).jpg
# Features derived for ../data\Basmati\basmati (6216).jpg
# Features derived for ../data\Basmati\basmati (11294).jpg
# Features derived for ../data\Basmati\basmati (10162).jpg
# Features derived for ../data\Basmati\basmati (12351).jpg
# Features derived for ../data\Basmati\basmati (11947).jpg
# Features derived for ../data\Basmati\basmati (10737).jpg
# Features derived for ../data\Basmati\basmati (12106).jpg
# Features derived for ../data\Basmati\basmati (10430).jpg
# Features derived for ../data\Basmati\basmati (14584).jpg
# Features derived for ../data\Basmati\basmati (6615).jpg
# Features derived for ../data\Basmati\basmati (7376).jpg
# Features derived for ../data\Basmati\basmati (8951).jpg
# Features derived for ../data\Basmati\basmati (174).jpg
# Features derived for ../data\Basmati\basmati (10230).jpg
# Features derived for ../data\Basmati\basmati (12635).jpg
# Features derived for ../data\Basmati\basmati (3873).jpg
# Features derived for ../data\Basmati\basmati (10777).jpg
# Features derived for ../data\Basmati\basmati (13551).jpg
# Features derived for ../data\Basmati\basmati (5037).jpg
# Features derived for ../data\Basmati\basmati (976).jpg
# Features derived for ../data\Basmati\basmati (6931).jpg
# Features derived for ../data\Basmati\basmati (14539).jpg
# Features derived for ../data\Basmati\basmati (6783).jpg
# Features derived for ../data\Basmati\basmati (5184).jpg
# Features derived for ../data\Basmati\basmati (1039).jpg
# Features derived for ../data\Ipsala\Ipsala (12191).jpg
# Features derived for ../data\Ipsala\Ipsala (3783).jpg
# Features derived for ../data\Ipsala\Ipsala (2457).jpg
# Features derived for ../data\Ipsala\Ipsala (287).jpg
# Features derived for ../data\Ipsala\Ipsala (1627).jpg
# Features derived for ../data\Ipsala\Ipsala (4458).jpg
# Features derived for ../data\Ipsala\Ipsala (12256).jpg
# Features derived for ../data\Ipsala\Ipsala (13295).jpg
# Features derived for ../data\Ipsala\Ipsala (9107).jpg
# Features derived for ../data\Ipsala\Ipsala (10392).jpg
# Features derived for ../data\Ipsala\Ipsala (4201).jpg
# Features derived for ../data\Ipsala\Ipsala (5419).jpg
# Features derived for ../data\Ipsala\Ipsala (14173).jpg
# Features derived for ../data\Ipsala\Ipsala (8687).jpg
# Features derived for ../data\Ipsala\Ipsala (6080).jpg
# Features derived for ../data\Ipsala\Ipsala (14943).jpg
# Features derived for ../data\Ipsala\Ipsala (9856).jpg
# Features derived for ../data\Ipsala\Ipsala (2071).jpg
# Features derived for ../data\Ipsala\Ipsala (14805).jpg
# Features derived for ../data\Ipsala\Ipsala (10653).jpg
# Features derived for ../data\Ipsala\Ipsala (12140).jpg
# Features derived for ../data\Ipsala\Ipsala (436).jpg
# Features derived for ../data\Ipsala\Ipsala (88).jpg
# Features derived for ../data\Ipsala\Ipsala (853).jpg
# Features derived for ../data\Ipsala\Ipsala (3581).jpg
# Features derived for ../data\Ipsala\Ipsala (14194).jpg
# Features derived for ../data\Ipsala\Ipsala (11856).jpg
# Features derived for ../data\Ipsala\Ipsala (8403).jpg
# Features derived for ../data\Ipsala\Ipsala (11678).jpg
# Features derived for ../data\Ipsala\Ipsala (14640).jpg
# Features derived for ../data\Ipsala\Ipsala (9032).jpg
# Features derived for ../data\Ipsala\Ipsala (2092).jpg
# Features derived for ../data\Ipsala\Ipsala (6990).jpg
# Features derived for ../data\Ipsala\Ipsala (8450).jpg
# Features derived for ../data\Ipsala\Ipsala (13764).jpg
# Features derived for ../data\Ipsala\Ipsala (4085).jpg
# Features derived for ../data\Ipsala\Ipsala (4542).jpg
# Features derived for ../data\Ipsala\Ipsala (11806).jpg
# Features derived for ../data\Ipsala\Ipsala (11464).jpg
# Features derived for ../data\Ipsala\Ipsala (4750).jpg
# Features derived for ../data\Ipsala\Ipsala (11003).jpg
# Features derived for ../data\Ipsala\Ipsala (1041).jpg
# Features derived for ../data\Ipsala\Ipsala (11568).jpg
# Features derived for ../data\Ipsala\Ipsala (14426).jpg
# Features derived for ../data\Ipsala\Ipsala (574).jpg
# Features derived for ../data\Ipsala\Ipsala (3645).jpg
# Features derived for ../data\Ipsala\Ipsala (9312).jpg
# Features derived for ../data\Ipsala\Ipsala (3363).jpg
# Features derived for ../data\Ipsala\Ipsala (13688).jpg
# Features derived for ../data\Ipsala\Ipsala (14342).jpg
# Features derived for ../data\Ipsala\Ipsala (8074).jpg
# Features derived for ../data\Ipsala\Ipsala (6291).jpg
# Features derived for ../data\Ipsala\Ipsala (552).jpg
# Features derived for ../data\Ipsala\Ipsala (1366).jpg
# Features derived for ../data\Ipsala\Ipsala (8034).jpg
# Features derived for ../data\Ipsala\Ipsala (13890).jpg
# Features derived for ../data\Ipsala\Ipsala (8753).jpg
# Features derived for ../data\Ipsala\Ipsala (13309).jpg
# Features derived for ../data\Ipsala\Ipsala (4955).jpg
# Features derived for ../data\Ipsala\Ipsala (6203).jpg
# Features derived for ../data\Ipsala\Ipsala (12931).jpg
# Features derived for ../data\Ipsala\Ipsala (13670).jpg
# Features derived for ../data\Ipsala\Ipsala (14393).jpg
# Features derived for ../data\Ipsala\Ipsala (13643).jpg
# Features derived for ../data\Ipsala\Ipsala (10724).jpg
# Features derived for ../data\Ipsala\Ipsala (4780).jpg
# Features derived for ../data\Ipsala\Ipsala (3843).jpg
# Features derived for ../data\Ipsala\Ipsala (12722).jpg
# Features derived for ../data\Ipsala\Ipsala (13561).jpg
# Features derived for ../data\Ipsala\Ipsala (11692).jpg
# Features derived for ../data\Ipsala\Ipsala (6758).jpg
# Features derived for ../data\Ipsala\Ipsala (14075).jpg
# Features derived for ../data\Ipsala\Ipsala (7177).jpg
# Features derived for ../data\Ipsala\Ipsala (21).jpg
# Features derived for ../data\Ipsala\Ipsala (7778).jpg
# Features derived for ../data\Ipsala\Ipsala (10020).jpg
# Features derived for ../data\Ipsala\Ipsala (7290).jpg
# Features derived for ../data\Ipsala\Ipsala (14155).jpg
# Features derived for ../data\Ipsala\Ipsala (4766).jpg
# Features derived for ../data\Ipsala\Ipsala (11478).jpg
# Features derived for ../data\Ipsala\Ipsala (8348).jpg
# Features derived for ../data\Ipsala\Ipsala (12316).jpg
# Features derived for ../data\Ipsala\Ipsala (6326).jpg
# Features derived for ../data\Ipsala\Ipsala (2929).jpg
# Features derived for ../data\Ipsala\Ipsala (13357).jpg
# Features derived for ../data\Ipsala\Ipsala (3655).jpg
# Features derived for ../data\Ipsala\Ipsala (2260).jpg
# Features derived for ../data\Ipsala\Ipsala (7670).jpg
# Features derived for ../data\Ipsala\Ipsala (4505).jpg
# Features derived for ../data\Ipsala\Ipsala (9672).jpg
# Features derived for ../data\Ipsala\Ipsala (10717).jpg
# Features derived for ../data\Ipsala\Ipsala (4237).jpg
# Features derived for ../data\Ipsala\Ipsala (14513).jpg
# Features derived for ../data\Ipsala\Ipsala (3791).jpg
# Features derived for ../data\Ipsala\Ipsala (11731).jpg
# Features derived for ../data\Ipsala\Ipsala (12472).jpg
# Features derived for ../data\Ipsala\Ipsala (786).jpg
# Features derived for ../data\Ipsala\Ipsala (14933).jpg
# Features derived for ../data\Ipsala\Ipsala (3976).jpg
# Features derived for ../data\Ipsala\Ipsala (12903).jpg
# Features derived for ../data\Jasmine\Jasmine (10449).jpg
# Features derived for ../data\Jasmine\Jasmine (13404).jpg
# Features derived for ../data\Jasmine\Jasmine (12833).jpg
# Features derived for ../data\Jasmine\Jasmine (8044).jpg
# Features derived for ../data\Jasmine\Jasmine (3757).jpg
# Features derived for ../data\Jasmine\Jasmine (14253).jpg
# Features derived for ../data\Jasmine\Jasmine (6962).jpg
# Features derived for ../data\Jasmine\Jasmine (6442).jpg
# Features derived for ../data\Jasmine\Jasmine (3406).jpg
# Features derived for ../data\Jasmine\Jasmine (5854).jpg
# Features derived for ../data\Jasmine\Jasmine (5942).jpg
# Features derived for ../data\Jasmine\Jasmine (44).jpg
# Features derived for ../data\Jasmine\Jasmine (851).jpg
# Features derived for ../data\Jasmine\Jasmine (4747).jpg
# Features derived for ../data\Jasmine\Jasmine (11701).jpg
# Features derived for ../data\Jasmine\Jasmine (13186).jpg
# Features derived for ../data\Jasmine\Jasmine (9739).jpg
# Features derived for ../data\Jasmine\Jasmine (10561).jpg
# Features derived for ../data\Jasmine\Jasmine (1747).jpg
# Features derived for ../data\Jasmine\Jasmine (10440).jpg
# Features derived for ../data\Jasmine\Jasmine (12877).jpg
# Features derived for ../data\Jasmine\Jasmine (9297).jpg
# Features derived for ../data\Jasmine\Jasmine (11286).jpg
# Features derived for ../data\Jasmine\Jasmine (13307).jpg
# Features derived for ../data\Jasmine\Jasmine (12147).jpg
# Features derived for ../data\Jasmine\Jasmine (1158).jpg
# Features derived for ../data\Jasmine\Jasmine (6879).jpg
# Features derived for ../data\Jasmine\Jasmine (8576).jpg
# Features derived for ../data\Jasmine\Jasmine (2988).jpg
# Features derived for ../data\Jasmine\Jasmine (11771).jpg
# Features derived for ../data\Jasmine\Jasmine (13793).jpg
# Features derived for ../data\Jasmine\Jasmine (7235).jpg
# Features derived for ../data\Jasmine\Jasmine (3847).jpg
# Features derived for ../data\Jasmine\Jasmine (13115).jpg
# Features derived for ../data\Jasmine\Jasmine (12519).jpg
# Features derived for ../data\Jasmine\Jasmine (1820).jpg
# Features derived for ../data\Jasmine\Jasmine (8913).jpg
# Features derived for ../data\Jasmine\Jasmine (2217).jpg
# Features derived for ../data\Jasmine\Jasmine (5600).jpg
# Features derived for ../data\Jasmine\Jasmine (10843).jpg
# Features derived for ../data\Jasmine\Jasmine (1152).jpg
# Features derived for ../data\Jasmine\Jasmine (11240).jpg
# Features derived for ../data\Jasmine\Jasmine (9667).jpg
# Features derived for ../data\Jasmine\Jasmine (7757).jpg
# Features derived for ../data\Jasmine\Jasmine (1809).jpg
# Features derived for ../data\Jasmine\Jasmine (2486).jpg
# Features derived for ../data\Jasmine\Jasmine (570).jpg
# Features derived for ../data\Jasmine\Jasmine (8967).jpg
# Features derived for ../data\Jasmine\Jasmine (1035).jpg
# Features derived for ../data\Jasmine\Jasmine (10632).jpg
# Features derived for ../data\Jasmine\Jasmine (2064).jpg
# Features derived for ../data\Jasmine\Jasmine (3520).jpg
# Features derived for ../data\Jasmine\Jasmine (5280).jpg
# Features derived for ../data\Jasmine\Jasmine (14612).jpg
# Features derived for ../data\Jasmine\Jasmine (2740).jpg
# Features derived for ../data\Jasmine\Jasmine (7995).jpg
# Features derived for ../data\Jasmine\Jasmine (11729).jpg
# Features derived for ../data\Jasmine\Jasmine (4248).jpg
# Features derived for ../data\Jasmine\Jasmine (3587).jpg
# Features derived for ../data\Jasmine\Jasmine (3298).jpg
# Features derived for ../data\Jasmine\Jasmine (13630).jpg
# Features derived for ../data\Jasmine\Jasmine (3211).jpg
# Features derived for ../data\Jasmine\Jasmine (5733).jpg
# Features derived for ../data\Jasmine\Jasmine (6705).jpg
# Features derived for ../data\Jasmine\Jasmine (9263).jpg
# Features derived for ../data\Jasmine\Jasmine (4598).jpg
# Features derived for ../data\Jasmine\Jasmine (4306).jpg
# Features derived for ../data\Jasmine\Jasmine (9210).jpg
# Features derived for ../data\Jasmine\Jasmine (11783).jpg
# Features derived for ../data\Jasmine\Jasmine (8165).jpg
# Features derived for ../data\Jasmine\Jasmine (7468).jpg
# Features derived for ../data\Jasmine\Jasmine (1179).jpg
# Features derived for ../data\Jasmine\Jasmine (1358).jpg
# Features derived for ../data\Jasmine\Jasmine (6290).jpg
# Features derived for ../data\Jasmine\Jasmine (12295).jpg
# Features derived for ../data\Jasmine\Jasmine (4364).jpg
# Features derived for ../data\Jasmine\Jasmine (10126).jpg
# Features derived for ../data\Jasmine\Jasmine (3482).jpg
# Features derived for ../data\Jasmine\Jasmine (14271).jpg
# Features derived for ../data\Jasmine\Jasmine (8419).jpg
# Features derived for ../data\Jasmine\Jasmine (14410).jpg
# Features derived for ../data\Jasmine\Jasmine (4304).jpg
# Features derived for ../data\Jasmine\Jasmine (6350).jpg
# Features derived for ../data\Jasmine\Jasmine (4804).jpg
# Features derived for ../data\Jasmine\Jasmine (220).jpg
# Features derived for ../data\Jasmine\Jasmine (7269).jpg
# Features derived for ../data\Jasmine\Jasmine (4749).jpg
# Features derived for ../data\Jasmine\Jasmine (542).jpg
# Features derived for ../data\Jasmine\Jasmine (2068).jpg
# Features derived for ../data\Jasmine\Jasmine (4288).jpg
# Features derived for ../data\Jasmine\Jasmine (12256).jpg
# Features derived for ../data\Jasmine\Jasmine (523).jpg
# Features derived for ../data\Jasmine\Jasmine (1202).jpg
# Features derived for ../data\Jasmine\Jasmine (10555).jpg
# Features derived for ../data\Jasmine\Jasmine (4307).jpg
# Features derived for ../data\Jasmine\Jasmine (13203).jpg
# Features derived for ../data\Jasmine\Jasmine (2304).jpg
# Features derived for ../data\Jasmine\Jasmine (216).jpg
# Features derived for ../data\Jasmine\Jasmine (1403).jpg
# Features derived for ../data\Jasmine\Jasmine (14976).jpg
# Features derived for ../data\Karacadag\Karacadag (6467).jpg
# Features derived for ../data\Karacadag\Karacadag (1999).jpg
# Features derived for ../data\Karacadag\Karacadag (14990).jpg
# Features derived for ../data\Karacadag\Karacadag (14582).jpg
# Features derived for ../data\Karacadag\Karacadag (1585).jpg
# Features derived for ../data\Karacadag\Karacadag (14530).jpg
# Features derived for ../data\Karacadag\Karacadag (3490).jpg
# Features derived for ../data\Karacadag\Karacadag (8648).jpg
# Features derived for ../data\Karacadag\Karacadag (12279).jpg
# Features derived for ../data\Karacadag\Karacadag (9210).jpg
# Features derived for ../data\Karacadag\Karacadag (1158).jpg
# Features derived for ../data\Karacadag\Karacadag (11037).jpg
# Features derived for ../data\Karacadag\Karacadag (9746).jpg
# Features derived for ../data\Karacadag\Karacadag (7542).jpg
# Features derived for ../data\Karacadag\Karacadag (6216).jpg
# Features derived for ../data\Karacadag\Karacadag (4359).jpg
# Features derived for ../data\Karacadag\Karacadag (8357).jpg
# Features derived for ../data\Karacadag\Karacadag (14939).jpg
# Features derived for ../data\Karacadag\Karacadag (4553).jpg
# Features derived for ../data\Karacadag\Karacadag (9625).jpg
# Features derived for ../data\Karacadag\Karacadag (5873).jpg
# Features derived for ../data\Karacadag\Karacadag (2846).jpg
# Features derived for ../data\Karacadag\Karacadag (2516).jpg
# Features derived for ../data\Karacadag\Karacadag (3484).jpg
# Features derived for ../data\Karacadag\Karacadag (4501).jpg
# Features derived for ../data\Karacadag\Karacadag (10322).jpg
# Features derived for ../data\Karacadag\Karacadag (2807).jpg
# Features derived for ../data\Karacadag\Karacadag (13103).jpg
# Features derived for ../data\Karacadag\Karacadag (12095).jpg
# Features derived for ../data\Karacadag\Karacadag (5791).jpg
# Features derived for ../data\Karacadag\Karacadag (4967).jpg
# Features derived for ../data\Karacadag\Karacadag (7757).jpg
# Features derived for ../data\Karacadag\Karacadag (8133).jpg
# Features derived for ../data\Karacadag\Karacadag (14503).jpg
# Features derived for ../data\Karacadag\Karacadag (8802).jpg
# Features derived for ../data\Karacadag\Karacadag (8540).jpg
# Features derived for ../data\Karacadag\Karacadag (320).jpg
# Features derived for ../data\Karacadag\Karacadag (6151).jpg
# Features derived for ../data\Karacadag\Karacadag (14891).jpg
# Features derived for ../data\Karacadag\Karacadag (10462).jpg
# Features derived for ../data\Karacadag\Karacadag (1492).jpg
# Features derived for ../data\Karacadag\Karacadag (13618).jpg
# Features derived for ../data\Karacadag\Karacadag (1234).jpg
# Features derived for ../data\Karacadag\Karacadag (13612).jpg
# Features derived for ../data\Karacadag\Karacadag (4170).jpg
# Features derived for ../data\Karacadag\Karacadag (1705).jpg
# Features derived for ../data\Karacadag\Karacadag (10026).jpg
# Features derived for ../data\Karacadag\Karacadag (7978).jpg
# Features derived for ../data\Karacadag\Karacadag (6396).jpg
# Features derived for ../data\Karacadag\Karacadag (8670).jpg
# Features derived for ../data\Karacadag\Karacadag (1950).jpg
# Features derived for ../data\Karacadag\Karacadag (13649).jpg
# Features derived for ../data\Karacadag\Karacadag (11431).jpg
# Features derived for ../data\Karacadag\Karacadag (9953).jpg
# Features derived for ../data\Karacadag\Karacadag (3876).jpg
# Features derived for ../data\Karacadag\Karacadag (2415).jpg
# Features derived for ../data\Karacadag\Karacadag (7302).jpg
# Features derived for ../data\Karacadag\Karacadag (6448).jpg
# Features derived for ../data\Karacadag\Karacadag (281).jpg
# Features derived for ../data\Karacadag\Karacadag (14951).jpg
# Features derived for ../data\Karacadag\Karacadag (427).jpg
# Features derived for ../data\Karacadag\Karacadag (969).jpg
# Features derived for ../data\Karacadag\Karacadag (6488).jpg
# Features derived for ../data\Karacadag\Karacadag (5355).jpg
# Features derived for ../data\Karacadag\Karacadag (1545).jpg
# Features derived for ../data\Karacadag\Karacadag (3174).jpg
# Features derived for ../data\Karacadag\Karacadag (14165).jpg
# Features derived for ../data\Karacadag\Karacadag (3076).jpg
# Features derived for ../data\Karacadag\Karacadag (5969).jpg
# Features derived for ../data\Karacadag\Karacadag (5985).jpg
# Features derived for ../data\Karacadag\Karacadag (12869).jpg
# Features derived for ../data\Karacadag\Karacadag (9131).jpg
# Features derived for ../data\Karacadag\Karacadag (12643).jpg
# Features derived for ../data\Karacadag\Karacadag (4817).jpg
# Features derived for ../data\Karacadag\Karacadag (2818).jpg
# Features derived for ../data\Karacadag\Karacadag (9600).jpg
# Features derived for ../data\Karacadag\Karacadag (6685).jpg
# Features derived for ../data\Karacadag\Karacadag (8970).jpg
# Features derived for ../data\Karacadag\Karacadag (2274).jpg
# Features derived for ../data\Karacadag\Karacadag (7795).jpg
# Features derived for ../data\Karacadag\Karacadag (3284).jpg
# Features derived for ../data\Karacadag\Karacadag (9910).jpg
# Features derived for ../data\Karacadag\Karacadag (7638).jpg
# Features derived for ../data\Karacadag\Karacadag (6763).jpg
# Features derived for ../data\Karacadag\Karacadag (14846).jpg
# Features derived for ../data\Karacadag\Karacadag (14103).jpg
# Features derived for ../data\Karacadag\Karacadag (2015).jpg
# Features derived for ../data\Karacadag\Karacadag (9825).jpg
# Features derived for ../data\Karacadag\Karacadag (5041).jpg
# Features derived for ../data\Karacadag\Karacadag (9197).jpg
# Features derived for ../data\Karacadag\Karacadag (279).jpg
# Features derived for ../data\Karacadag\Karacadag (6081).jpg
# Features derived for ../data\Karacadag\Karacadag (10805).jpg
# Features derived for ../data\Karacadag\Karacadag (254).jpg
# Features derived for ../data\Karacadag\Karacadag (1557).jpg
# Features derived for ../data\Karacadag\Karacadag (644).jpg
# Features derived for ../data\Karacadag\Karacadag (13604).jpg
# Features derived for ../data\Karacadag\Karacadag (11457).jpg
# Features derived for ../data\Karacadag\Karacadag (10630).jpg
# Features derived for ../data\Karacadag\Karacadag (4444).jpg

# %%
# df.to_parquet('../training_data/rice_feature_data.parquet')

# %%
# plot one example of an original image and
# the original image with the contour and
# the original image with the ellipse
plt.figure(figsize=(6, 10))
chosen_images = [0, 100, 200, 300, 400]
roll = 0
for i, species in zip(chosen_images, folders):
    roll+=1
    im = ims[i]
    imc = ims_with_contours[i]
    ime = ims_with_ellipses[i]

    plt.subplot(5,3,roll)
    plt.title('Original image, {}'.format(species), fontsize=6)
    plt.imshow(im)
    plt.xticks([])
    plt.yticks([])
    
    roll+=1

    plt.subplot(5,3,roll)
    plt.title('Original image with contour, {}'.format(species),
              fontsize=6)
    plt.imshow(imc)
    plt.xticks([])
    plt.yticks([])
    
    roll+=1
    
    plt.subplot(5,3,roll)
    plt.title('Original image with ellipse, {}'.format(species),
              fontsize=6)
    plt.imshow(ime)
    plt.xticks([])
    plt.yticks([])

plt.tight_layout();

# %% [markdown]
# Determine the maximum variance of the Cr component for each rice species. Which rice species has the smallest value?

# %%
df.groupby('class').var_cr.max()
# Out:
# class
# Arb     1.539615
# Bas     7.551458
# Ips     5.333669
# Jas    14.891400
# Kar     1.736069
# Name: var_cr, dtype: float64

# %% [markdown]
# Mini-exam question: <br>
# **7. Determine the maximum variance of the Cr component for each rice species. Which rice species has the smallest value?** <br>
# Answer: Arborio

# %% [markdown]
# Determine the minimum equivalent diameter for each rice species. Which rice species has the largest value?

# %%
df.groupby('class').equivalent_diameter.min()
# Out:
# class
# Arb     81.223708
# Bas     81.805544
# Ips    113.647446
# Jas     78.513625
# Kar     81.011809
# Name: equivalent_diameter, dtype: float64

# %% [markdown]
# Mini-exam question: <br>
# **8. Determine the minimum equivalent diameter for each rice species. Which rice species has the largest value?** <br>
# Answer: Ipsala

# %% [markdown]
# Determine the minimum, maximum and median equivalent diameter for Basmati rice samples. <br>
# Compare the equivalent diameter value of the test_image to these values. <br>

# %%
df[df.class_int == 1].equivalent_diameter.describe()
# Out:
# count    100.000000
# mean      95.734143
# std        5.637933
# min       81.805544
# 25%       92.061480
# 50%       96.444960
# 75%       99.973800
# max      106.250546
# Name: equivalent_diameter, dtype: float64

# %% [markdown]
# Mini-exam question: <br>
# **9. Determine the minimum, maximum and median equivalent diameter for Basmati. Where in this range does the equivalent diameter of the test_image lie?** <br>
# Answer: The equivalent diameter for the test image is 97 pixels. Thus, the value is close to the median value of the equivalent diameter for Basmati samples.

# %% [markdown]
# Does a high value of compactness mean that the rice is rather round or thin?

# %%
# a high value of compactness
plt.figure(figsize=(5,5))
plt.imshow(ims[df[
    df.compactness == df.compactness.max()].index[0]]);

# %%
# a small value of compactness
plt.figure(figsize=(5,5))
plt.imshow(ims[df[
    df.compactness == df.compactness.min()].index[0]]);

# %% [markdown]
# Mini-exam question: <br>
# **10. Does a high value of compactness mean that the rice is rather round or thin?** <br>
# Answer: Round
